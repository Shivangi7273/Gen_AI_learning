# %%
# %pip install -q guardrails-ai
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for lxml (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [113 lines of output]
#       Building lxml version 4.9.4.
#       <string>:67: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#       Building without Cython.
#       Building against pre-built libxml2 andl libxslt libraries
#       C:\Users\shivangi.d.tripathi\AppData\Local\Temp\pip-build-env-dnmtbhkj\overlay\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: BSD License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\builder.py -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\cssselect.py -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\doctestcompare.py -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\ElementInclude.py -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\pyclasslookup.py -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\sax.py -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\usedoctest.py -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\_elementpath.py -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\__init__.py -> build\lib.win-amd64-cpython-313\lxml
#       creating build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\__init__.py -> build\lib.win-amd64-cpython-313\lxml\includes
#       creating build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\builder.py -> build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\clean.py -> build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\defs.py -> build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\diff.py -> build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\ElementSoup.py -> build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\formfill.py -> build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\html5parser.py -> build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\soupparser.py -> build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\usedoctest.py -> build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\_diffcommand.py -> build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\_html5builder.py -> build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\_setmixin.py -> build\lib.win-amd64-cpython-313\lxml\html
#       copying src\lxml\html\__init__.py -> build\lib.win-amd64-cpython-313\lxml\html
#       creating build\lib.win-amd64-cpython-313\lxml\isoschematron
#       copying src\lxml\isoschematron\__init__.py -> build\lib.win-amd64-cpython-313\lxml\isoschematron
#       copying src\lxml\etree.h -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\etree_api.h -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\lxml.etree.h -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\lxml.etree_api.h -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\etree.pyx -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\objectify.pyx -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\apihelpers.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\classlookup.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\cleanup.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\debug.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\docloader.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\dtd.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\extensions.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\iterparse.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\nsclasses.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\objectpath.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\parser.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\parsertarget.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\proxy.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\public-api.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\readonlytree.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\relaxng.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\saxparser.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\schematron.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\serializer.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\xinclude.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\xmlerror.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\xmlid.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\xmlschema.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\xpath.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\xslt.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\xsltext.pxi -> build\lib.win-amd64-cpython-313\lxml
#       copying src\lxml\includes\c14n.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\config.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\dtdvalid.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\etreepublic.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\htmlparser.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\relaxng.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\schematron.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\tree.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\uri.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\xinclude.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\xmlerror.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\xmlparser.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\xmlschema.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\xpath.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\xslt.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\__init__.pxd -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\etree_defs.h -> build\lib.win-amd64-cpython-313\lxml\includes
#       copying src\lxml\includes\lxml-version.h -> build\lib.win-amd64-cpython-313\lxml\includes
#       creating build\lib.win-amd64-cpython-313\lxml\isoschematron\resources\rng
#       copying src\lxml\isoschematron\resources\rng\iso-schematron.rng -> build\lib.win-amd64-cpython-313\lxml\isoschematron\resources\rng
#       creating build\lib.win-amd64-cpython-313\lxml\isoschematron\resources\xsl
#       copying src\lxml\isoschematron\resources\xsl\RNG2Schtrn.xsl -> build\lib.win-amd64-cpython-313\lxml\isoschematron\resources\xsl
#       copying src\lxml\isoschematron\resources\xsl\XSD2Schtrn.xsl -> build\lib.win-amd64-cpython-313\lxml\isoschematron\resources\xsl
#       creating build\lib.win-amd64-cpython-313\lxml\isoschematron\resources\xsl\iso-schematron-xslt1
#       copying src\lxml\isoschematron\resources\xsl\iso-schematron-xslt1\iso_abstract_expand.xsl -> build\lib.win-amd64-cpython-313\lxml\isoschematron\resources\xsl\iso-schematron-xslt1
#       copying src\lxml\isoschematron\resources\xsl\iso-schematron-xslt1\iso_dsdl_include.xsl -> build\lib.win-amd64-cpython-313\lxml\isoschematron\resources\xsl\iso-schematron-xslt1
#       copying src\lxml\isoschematron\resources\xsl\iso-schematron-xslt1\iso_schematron_message.xsl -> build\lib.win-amd64-cpython-313\lxml\isoschematron\resources\xsl\iso-schematron-xslt1
#       copying src\lxml\isoschematron\resources\xsl\iso-schematron-xslt1\iso_schematron_skeleton_for_xslt1.xsl -> build\lib.win-amd64-cpython-313\lxml\isoschematron\resources\xsl\iso-schematron-xslt1
#       copying src\lxml\isoschematron\resources\xsl\iso-schematron-xslt1\iso_svrl_for_xslt1.xsl -> build\lib.win-amd64-cpython-313\lxml\isoschematron\resources\xsl\iso-schematron-xslt1
#       copying src\lxml\isoschematron\resources\xsl\iso-schematron-xslt1\readme.txt -> build\lib.win-amd64-cpython-313\lxml\isoschematron\resources\xsl\iso-schematron-xslt1
#       running build_ext
#       building 'lxml.etree' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for lxml
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (lxml)

# %%
# %pip install guardrails-ai --upgrade

# %%
! guardrails configure
# Out:
# 'guardrails' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %pip install nemoguardrails
# Out:
# Collecting nemoguardrails
#   Downloading nemoguardrails-0.14.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: aiohttp>=3.10.11 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (3.12.12)
# Collecting annoy>=1.17.3 (from nemoguardrails)
#   Downloading annoy-1.17.3.tar.gz (647 kB)
#      ---------------------------------------- 0.0/647.5 kB ? eta -:--:--
#      -------------------------------------- 647.5/647.5 kB 5.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: fastapi>=0.103.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (0.115.9)
# Collecting fastembed<=0.6.0,>=0.2.2 (from nemoguardrails)
#   Downloading fastembed-0.6.0-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: httpx>=0.24.1 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (0.28.1)
# Requirement already satisfied: jinja2>=3.1.6 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (3.1.6)
# Requirement already satisfied: langchain<0.4.0,>=0.2.14 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (0.3.25)
# Requirement already satisfied: langchain-community<0.4.0,>=0.2.5 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (0.3.25)
# Requirement already satisfied: langchain-core<0.4.0,>=0.2.14 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (0.3.65)
# Collecting lark>=1.1.7 (from nemoguardrails)
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: nest-asyncio>=1.5.6 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (1.6.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (2.3.0)
# Requirement already satisfied: prompt-toolkit>=3.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (3.0.51)
# Requirement already satisfied: pydantic>=1.10 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (2.11.5)
# Requirement already satisfied: pyyaml>=6.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (6.0.2)
# Requirement already satisfied: rich>=13.5.2 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (14.0.0)
# Collecting simpleeval>=0.9.13 (from nemoguardrails)
#   Downloading simpleeval-1.0.3-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: starlette>=0.27.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (0.45.3)
# Requirement already satisfied: typer>=0.8 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (0.16.0)
# Requirement already satisfied: uvicorn>=0.23 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from nemoguardrails) (0.34.3)
# Collecting watchdog>=3.0.0 (from nemoguardrails)
#   Using cached watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from aiohttp>=3.10.11->nemoguardrails) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from aiohttp>=3.10.11->nemoguardrails) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from aiohttp>=3.10.11->nemoguardrails) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from aiohttp>=3.10.11->nemoguardrails) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from aiohttp>=3.10.11->nemoguardrails) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from aiohttp>=3.10.11->nemoguardrails) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from aiohttp>=3.10.11->nemoguardrails) (1.20.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from fastapi>=0.103.0->nemoguardrails) (4.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.20 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from fastembed<=0.6.0,>=0.2.2->nemoguardrails) (0.33.0)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from fastembed<=0.6.0,>=0.2.2->nemoguardrails) (0.7.3)
# Requirement already satisfied: mmh3<6.0.0,>=4.1.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from fastembed<=0.6.0,>=0.2.2->nemoguardrails) (5.1.0)
# Requirement already satisfied: numpy>=2.1.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from fastembed<=0.6.0,>=0.2.2->nemoguardrails) (2.2.6)
# Requirement already satisfied: onnxruntime>1.20.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from fastembed<=0.6.0,>=0.2.2->nemoguardrails) (1.22.0)
# Requirement already satisfied: pillow<12.0.0,>=10.3.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from fastembed<=0.6.0,>=0.2.2->nemoguardrails) (10.4.0)
# Collecting py-rust-stemmers<0.2.0,>=0.1.0 (from fastembed<=0.6.0,>=0.2.2->nemoguardrails)
#   Downloading py_rust_stemmers-0.1.5-cp313-none-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3.0,>=2.31 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from fastembed<=0.6.0,>=0.2.2->nemoguardrails) (2.32.4)
# Requirement already satisfied: tokenizers<1.0,>=0.15 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from fastembed<=0.6.0,>=0.2.2->nemoguardrails) (0.21.1)
# Requirement already satisfied: tqdm<5.0,>=4.66 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from fastembed<=0.6.0,>=0.2.2->nemoguardrails) (4.67.1)
# Requirement already satisfied: anyio in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from httpx>=0.24.1->nemoguardrails) (1.4.0)
# Requirement already satisfied: certifi in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from httpx>=0.24.1->nemoguardrails) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from httpx>=0.24.1->nemoguardrails) (1.0.9)
# Requirement already satisfied: idna in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from httpx>=0.24.1->nemoguardrails) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->nemoguardrails) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from jinja2>=3.1.6->nemoguardrails) (3.0.2)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from langchain<0.4.0,>=0.2.14->nemoguardrails) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from langchain<0.4.0,>=0.2.14->nemoguardrails) (0.3.45)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from langchain<0.4.0,>=0.2.14->nemoguardrails) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from langchain-community<0.4.0,>=0.2.5->nemoguardrails) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from langchain-community<0.4.0,>=0.2.5->nemoguardrails) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from langchain-community<0.4.0,>=0.2.5->nemoguardrails) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from langchain-community<0.4.0,>=0.2.5->nemoguardrails) (0.4.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from langchain-core<0.4.0,>=0.2.14->nemoguardrails) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from langchain-core<0.4.0,>=0.2.14->nemoguardrails) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from pandas<3,>=1.4.0->nemoguardrails) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from pandas<3,>=1.4.0->nemoguardrails) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from pandas<3,>=1.4.0->nemoguardrails) (2025.2)
# Requirement already satisfied: wcwidth in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from prompt-toolkit>=3.0->nemoguardrails) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from pydantic>=1.10->nemoguardrails) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from pydantic>=1.10->nemoguardrails) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from pydantic>=1.10->nemoguardrails) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from rich>=13.5.2->nemoguardrails) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from rich>=13.5.2->nemoguardrails) (2.19.1)
# Collecting anyio (from httpx>=0.24.1->nemoguardrails)
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: click>=8.0.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from typer>=0.8->nemoguardrails) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from typer>=0.8->nemoguardrails) (1.5.4)
# Requirement already satisfied: sniffio>=1.1 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from anyio->httpx>=0.24.1->nemoguardrails) (1.3.1)
# Requirement already satisfied: colorama in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from click>=8.0.0->typer>=0.8->nemoguardrails) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.2.5->nemoguardrails) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.2.5->nemoguardrails) (0.9.0)
# Requirement already satisfied: filelock in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from huggingface-hub<1.0,>=0.20->fastembed<=0.6.0,>=0.2.2->nemoguardrails) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from huggingface-hub<1.0,>=0.20->fastembed<=0.6.0,>=0.2.2->nemoguardrails) (2025.3.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.2.14->nemoguardrails) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.2.14->nemoguardrails) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.2.14->nemoguardrails) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.2.14->nemoguardrails) (0.23.0)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from loguru<0.8.0,>=0.7.2->fastembed<=0.6.0,>=0.2.2->nemoguardrails) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.5.2->nemoguardrails) (0.1.2)
# Requirement already satisfied: coloredlogs in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from onnxruntime>1.20.0->fastembed<=0.6.0,>=0.2.2->nemoguardrails) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from onnxruntime>1.20.0->fastembed<=0.6.0,>=0.2.2->nemoguardrails) (25.2.10)
# Requirement already satisfied: protobuf in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from onnxruntime>1.20.0->fastembed<=0.6.0,>=0.2.2->nemoguardrails) (5.29.5)
# Requirement already satisfied: sympy in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from onnxruntime>1.20.0->fastembed<=0.6.0,>=0.2.2->nemoguardrails) (1.14.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.2.5->nemoguardrails) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->nemoguardrails) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from requests<3.0,>=2.31->fastembed<=0.6.0,>=0.2.2->nemoguardrails) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from requests<3.0,>=2.31->fastembed<=0.6.0,>=0.2.2->nemoguardrails) (2.4.0)
# Requirement already satisfied: greenlet>=1 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain<0.4.0,>=0.2.14->nemoguardrails) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.2.5->nemoguardrails) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from coloredlogs->onnxruntime>1.20.0->fastembed<=0.6.0,>=0.2.2->nemoguardrails) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from sympy->onnxruntime>1.20.0->fastembed<=0.6.0,>=0.2.2->nemoguardrails) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\shivangi\my_learning\2_langchain\langchainenv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>1.20.0->fastembed<=0.6.0,>=0.2.2->nemoguardrails) (3.5.4)
# Downloading nemoguardrails-0.14.1-py3-none-any.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ----------- ---------------------------- 3.1/11.1 MB 16.3 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.1 MB 21.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 19.5 MB/s eta 0:00:00
# Downloading fastembed-0.6.0-py3-none-any.whl (85 kB)
# Downloading lark-1.2.2-py3-none-any.whl (111 kB)
# Downloading simpleeval-1.0.3-py3-none-any.whl (15 kB)
# Using cached watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Downloading py_rust_stemmers-0.1.5-cp313-none-win_amd64.whl (209 kB)
# Building wheels for collected packages: annoy
#   Building wheel for annoy (pyproject.toml): started
#   Building wheel for annoy (pyproject.toml): finished with status 'error'
# Failed to build annoy
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for annoy (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [12 lines of output]
#       C:\Users\shivangi.d.tripathi\AppData\Local\Temp\pip-build-env-ffu25nwv\overlay\Lib\site-packages\setuptools\_distutils\dist.py:289: UserWarning: Unknown distribution option: 'tests_require'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-313\annoy
#       copying annoy\__init__.py -> build\lib.win-amd64-cpython-313\annoy
#       copying annoy\__init__.pyi -> build\lib.win-amd64-cpython-313\annoy
#       copying annoy\py.typed -> build\lib.win-amd64-cpython-313\annoy
#       running build_ext
#       building 'annoy.annoylib' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for annoy
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (annoy)
