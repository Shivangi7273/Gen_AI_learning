# %%
# ! pip install --upgrade datasets
# ! pip install --upgrade transformers

# %%
# for doing efficient stuff - PEFT (Performance Efficient Fine Tuning) -

# ! pip install --upgrade peft
# ! pip install --upgrade trl
# ! pip install bitsandbytes
# ! pip install accelerate

# %%
# for logging and visualizing training progress -
# ! pip install tensorboard

# if creating a new dataset then useful for creating *.jsonl files
# ! pip install jsonlines

# %%
# logging in to Hugging Face ecosystem -
# from huggingface_hub import notebook_login
# from google.colab import userdata
# hf_token = userdata.get("hftoken")
# notebook_login()

# %%
from huggingface_hub import notebook_login

# %%
# ! pip install ipywidgets
## in order to use the command 'notebook_login()'

# %%
notebook_login()

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
from IPython.display import display, Image
import time
import gc
from torch.utils.data import Dataset, DataLoader

device = 'cuda' if torch.cuda.is_available() else 'cpu'

def print_gpu_utilization():
    allocated = torch.cuda.memory_allocated() / (1024**2)
    reserved = torch.cuda.memory_reserved() / (1024**2)
    print(f"GPU memory usage>>>> Allocated: {allocated:.2f} MB ||| Reserved: {reserved:.2f} MB.")

def flush():
    torch.cuda.empty_cache()
    gc.collect()
    torch.cuda.empty_cache()
    gc.collect()

# %%
DEFAULT_MODEL = "meta-llama/Llama-3.2-1B-Instruct"
model = AutoModelForCausalLM.from_pretrained(
    DEFAULT_MODEL,
    device_map = device,
    torch_dtype = torch.bfloat16 
)

tokenizer = AutoTokenizer.from_pretrained(DEFAULT_MODEL, use_safetensors = True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Shivangi\My_Learning\2_LangChain\langchainEnv\Lib\site-packages\huggingface_hub\utils\_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File c:\Shivangi\My_Learning\2_LangChain\langchainEnv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/meta-llama/Llama-3.2-1B-Instruct/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# ...

# %%
print(model.get_memory_footprint() / (1024*1024))
